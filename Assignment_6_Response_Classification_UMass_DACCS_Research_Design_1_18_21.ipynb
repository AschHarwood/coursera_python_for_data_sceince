# %% [markdown]
# <a href="https://colab.research.google.com/github/AschHarwood/coursera_python_for_data_sceince/blob/master/Assignment_6_Response_Classification_UMass_DACCS_Research_Design_1_18_21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Responses - Sheet1.csv')

# %%
df
# Out:
#                                               Response              Category
# 0    105 Summers off important when raising family,...            Flexibilty
# 1    125 Hours - Summer off - vacations with my chi...            Flexibilty
# 2    15 My husband died when I was 35 years old. I ...            Flexibilty
# 3    190 Job burn out in retail management. Dissati...            Flexibilty
# 4    239 Knowing that I wanted a family and not wan...            Flexibilty
# ..                                                 ...                   ...
# 116  46 I enjoyed teaching swim lessons while in hi...  Prior work with kids
# 117  50 I enjoy the learning process. I also like w...    Source of pleasure
# 118             124 Learning new things is my passion.    Source of pleasure
# 119  108 I love to instruct. Weekends, holidays wit...    Source of pleasure
# 120  131 I enjoyed teaching kids and helping them l...    Source of pleasure
#
# [121 rows x 2 columns]

# %%
counts = df.groupby('Category').count()

# %%
counts
# Out:
#                             Response
# Category
# Flexibilty                         7
# Good at it                         6
# Interest in subject matter         9
# Love kids                         30
# Make a difference                 27
# No response                        4
# Outside influence                 31
# Prior work with kids               3
# Source of pleasure                 4

# %%
import plotly.express as px

# %%
fig = px.bar(x=counts.index, y=counts.Response, title='Major Factors for Becoming a Teacher', labels={'x': 'Major Factors', 'y': 'Number of Respondents'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9cd7326b-4d7b-42ce-b078-bdb9b90279cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9cd7326b-4d7b-42ce-b078-bdb9b90279cd")) {
#                     Plotly.newPlot(
#                         '9cd7326b-4d7b-42ce-b078-bdb9b90279cd',
# ...
